# %% [markdown]
# task 22

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.signal as sig
from python_speech_features import mfcc
from python_speech_features import logfbank
import scipy.io.wavfile as wav

# %%
(rate,sig) = wav.read("dft_test.wav")
mfcc_feat = mfcc(sig,rate)
fbank_feat = logfbank(sig,rate)
print(fbank_feat[1:3,:])
plt.plot(mfcc_feat)
plt.show()
# Out:
# WARNING:root:frame length (1200) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# WARNING:root:frame length (1200) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# [[1.97654273 3.19109444 4.42114472 5.348876   4.9586426  5.60391275
#   5.66299237 6.26285164 5.8239083  6.22359242 7.16342561 7.15156781
#   7.21388718 4.81754837 2.03231731 0.54276707 1.1605376  1.74866048
#   1.77588026 1.68206389 1.92257545 2.04112267 1.69413322 1.30770917
#   1.40609001 4.84956599]
#  [0.81386652 3.63299834 4.81725539 5.61204887 6.07618323 6.13592929
#   6.43384115 7.16472182 6.59758328 6.94211443 7.55386103 7.92433743
#   7.90537906 5.77674963 2.98907153 2.50230323 2.06935892 1.88570603
#   1.77994554 2.26114861 2.03649035 1.7878779  1.92249391 1.58098122
#   2.36077164 5.53745282]]

# %% [markdown]
# Task #23

# %%
import cv2

filename = 'cat.jpg'
W = 1000.
oriimg = cv2.imread(filename,cv2.COLOR_BGR2GRAY)
height, width, depth = oriimg.shape
imgScale = W/width
newX,newY = oriimg.shape[1]*imgScale, oriimg.shape[0]*imgScale
newimg = cv2.resize(oriimg,(int(newX),int(newY)))
#cv2.imshow("Show by CV2", newimg)

plt.figure()
plt.imshow(oriimg)
plt.show()

plt.figure()
plt.imshow(newimg)
plt.show()

# %% [markdown]
# task 24

# %%
img = cv2.imread('cat.jpg',0)

dft = cv2.dft(np.float32(img),flags = cv2.DFT_COMPLEX_OUTPUT)
dft_shift = np.fft.fftshift(dft)

magnitude_spectrum = 20*np.log(cv2.magnitude(dft_shift[:,:,0],dft_shift[:,:,1]))

plt.subplot(121),plt.imshow(img, cmap = 'gray')
plt.title('Output Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(magnitude_spectrum, cmap = 'gray')
plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# task 25

# %%
def shade(imag, percent):
    tinted_imag = imag * (1 - percent)
    return tinted_imag

def vertical_gradient_line(image, reverse=False):
    number_of_columns = image.shape[1]
    if reverse:
        C = np.linspace(1, 0, number_of_columns)
    else:
        C = np.linspace(0, 1, number_of_columns)
    C = np.dstack((C, C, C))
    return C

def horizontal_gradient_line(image, reverse=False):
    number_of_rows, number_of_columns = image.shape[:2]
    C = np.linspace(1, 0, number_of_rows)
    C = C[np.newaxis,:]
    C = np.concatenate((C, C, C)).transpose()
    C = C[:, np.newaxis]
    return C

plt.subplot(2,1,1)
windmills = plt.imread('panda2.jpg')
tinted_windmills = shade(windmills, 0.9)
plt.imshow(tinted_windmills)

plt.subplot(2,1,2)
windmills = plt.imread('cat2.jpg')
tinted_windmills = shade(windmills, 0.9)
plt.imshow(tinted_windmills)

plt.show()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# task 27

# %%
##Text data compression:
import base64
import zlib
data = b'2,3,5,1,13,7,17,11,89,1,233,29,61,47,1597,19,37,41,421,199,28657,23,3001,521,53,281,514229,31,557,2207,19801,3571,141961,107,73,9349,135721,2161,2789,211,433494437,43,109441,139,2971215073,1103,97,101,6376021,90481,953,5779,661,14503,797,59,353,2521,4513,3010349,35239681,1087,14736206161,9901,269,67,137,71,6673,103681,9375829,54018521,230686501,29134601,988681,79,157,1601,2269,370248451,99194853094755497,83,9521,6709,173,263,1069,181,741469,4969,4531100550901,6643838879,761,769,193,599786069,197,401,743519377,919,519121,103,8288823481,119218851371,1247833,11128427,827728777,331,1459000305513721,10745088481,677,229,1381,347,29717,709,159512939815855788121'
compressed_data = base64.b64encode(zlib.compress(data))
print(compressed_data)
# print (data)
# Out:
# b'...'
